# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from tqdm import tqdm

# %%
train=pd.read_csv(r"C:\Users\alok\Documents\ML_Deep_Learning_stuff/UNSW_NB15_training-set.csv", na_values=["-"])  # service column contains "-" so to replace it with NaN, na_values is used 
train
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.121478   tcp     NaN   FIN      6      4     258     172
# 1            2  0.649902   tcp     NaN   FIN     14     38     734   42014
# 2            3  1.623129   tcp     NaN   FIN      8     16     364   13186
# 3            4  1.681642   tcp     ftp   FIN     12     12     628     770
# 4            5  0.449454   tcp     NaN   FIN     10      6     534     268
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 175336  175337  0.000009   udp     dns   INT      2      0     114       0
# 175337  175338  0.505762   tcp     NaN   FIN     10      8     620     354
# 175338  175339  0.000009   udp     dns   INT      2      0     114       0
# 175339  175340  0.000009   udp     dns   INT      2      0     114       0
# 175340  175341  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0           74.087490  ...                 1               1             0
# 1           78.473372  ...                 1               2             0
# 2           14.170161  ...                 1               3             0
# 3           13.677108  ...                 1               3             1
# 4           33.373826  ...                 1              40             0
# ...               ...  ...               ...             ...           ...
# 175336  111111.107200  ...                13              24             0
# 175337      33.612649  ...                 1               2             0
# 175338  111111.107200  ...                 3              13             0
# 175339  111111.107200  ...                14              30             0
# 175340  111111.107200  ...                16              30             0
#
#         ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0                0                 0           1           1                0
# 1                0                 0           1           6                0
# 2                0                 0           2           6                0
# 3                1                 0           2           1                0
# 4                0                 0           2          39                0
# ...            ...               ...         ...         ...              ...
# 175336           0                 0          24          24                0
# 175337           0                 0           1           1                0
# 175338           0                 0           3          12                0
# 175339           0                 0          30          30                0
# 175340           0                 0          30          30                0
#
#         attack_cat  label
# 0           Normal      0
# 1           Normal      0
# 2           Normal      0
# 3           Normal      0
# 4           Normal      0
# ...            ...    ...
# 175336     Generic      1
# 175337   Shellcode      1
# 175338     Generic      1
# 175339     Generic      1
# 175340     Generic      1
#
# [175341 rows x 45 columns]

# %%
train.columns
# Out:
# Index(['id', 'dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes',
#        'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss',
#        'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin',
#        'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth',
#        'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm',
#        'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
#        'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm',
#        'ct_srv_dst', 'is_sm_ips_ports', 'attack_cat', 'label'],
#       dtype='object')

# %%
total = len(train)*1.
ax=sns.countplot(x="label", data=train)
# for p in ax.patches:
#     print(p)
#     ax.annotate('{:.1f}%'.format(100*p.get_height()/total), (p.get_x()+0.3, p.get_height()+5))

# #put 11 ticks (therefore 10 steps), from 0 to the total number of rows in the dataframe
ax.yaxis.set_ticks(np.linspace(0, total, 11))
# print(ax.yaxis.get_majorticklocs())
# #adjust the ticklabel to the desired format, without changing the position of the ticks. 
# ax.set_yticklabels(map('{:.1f}%'.format, 100*ax.yaxis.get_majorticklocs()/total))
# plt.savefig('class_label.png')
plt.show()

# %%
cat_feature = train.select_dtypes(include=['category', object]).columns
cat_feature
# Out:
# Index(['proto', 'service', 'state', 'attack_cat'], dtype='object')

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 10))
plt.subplots_adjust(hspace = 0.4)
for col, subplot in zip(cat_feature, ax.flatten()):
    sns.countplot(train[col], ax=subplot)
    for labelx, labely in zip(subplot.get_xticklabels(), subplot.get_yticklabels()):
            labelx.set_rotation(45)
            labely.set_rotation(35) 
plt.show()


# for col in cat_feature:
#     sns.countplot(train[col],data=train)
#     plt.show()

# %% [markdown]
# # 3.2 visualizing numerical data and its distribution

# %%
num_features = train.drop(['id','label'], axis=1).select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).columns
print(num_features)
print(num_features.size)
# Out:
# Index(['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl',
#        'sload', 'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit',
#        'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 'ackdat', 'smean',
#        'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src',
#        'ct_state_ttl', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm',
#        'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd',
#        'ct_src_ltm', 'ct_srv_dst', 'is_sm_ips_ports'],
#       dtype='object')
# 39

# %%
fig, ax = plt.subplots(20, 2, figsize=(30, 50))
plt.subplots_adjust(hspace = 0.4)
for col, splot in zip(num_features, ax.flatten()):
    sns.distplot(train[col], ax=splot)
plt.savefig('num_f.png')
plt.show()

# %% [markdown]
# ## 3.3 Correlation of data .. discards object (categorical) data .. only accepts integer or float

# %%
train_corr = train.corr()  
print(type(train_corr))
train_corr.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# id                   float64
# dur                  float64
# spkts                float64
# dpkts                float64
# sbytes               float64
# dbytes               float64
# rate                 float64
# sttl                 float64
# dttl                 float64
# sload                float64
# dload                float64
# sloss                float64
# dloss                float64
# sinpkt               float64
# dinpkt               float64
# sjit                 float64
# djit                 float64
# swin                 float64
# stcpb                float64
# dtcpb                float64
# dwin                 float64
# tcprtt               float64
# synack               float64
# ackdat               float64
# smean                float64
# dmean                float64
# trans_depth          float64
# response_body_len    float64
# ct_srv_src           float64
# ct_state_ttl         float64
# ct_dst_ltm           float64
# ct_src_dport_ltm     float64
# ct_dst_sport_ltm     float64
# ct_dst_src_ltm       float64
# is_ftp_login         float64
# ct_ftp_cmd           float64
# ct_flw_http_mthd     float64
# ct_src_ltm           float64
# ct_srv_dst           float64
# is_sm_ips_ports      float64
# label                float64
# dtype: object

# %%
train_corr = train.corr()

# %%
plt.figure(figsize=(30,20))
sns.heatmap(train_corr, annot=True)
plt.savefig('corr_mat.png')
plt.show()

# %%
high_corr_var=np.where(train_corr>0.95)

# %%
high_corr_var
# Out:
# (array([ 0,  1,  2,  2,  2,  3,  3,  3,  4,  4,  4,  5,  5,  5,  6,  7,  8,
#          9, 10, 11, 11, 11, 12, 12, 12, 13, 14, 15, 16, 17, 17, 18, 19, 20,
#         20, 21, 22, 23, 24, 25, 26, 27, 28, 28, 28, 29, 30, 30, 31, 31, 32,
#         33, 33, 33, 34, 34, 35, 35, 36, 37, 38, 38, 38, 39, 40],
#        dtype=int64),
#  array([ 0,  1,  2,  4, 11,  3,  5, 12,  2,  4, 11,  3,  5, 12,  6,  7,  8,
#          9, 10,  2,  4, 11,  3,  5, 12, 13, 14, 15, 16, 17, 20, 18, 19, 17,
#         20, 21, 22, 23, 24, 25, 26, 27, 28, 33, 38, 29, 30, 31, 30, 31, 32,
#         28, 33, 38, 34, 35, 34, 35, 36, 37, 28, 33, 38, 39, 40],
#        dtype=int64))

# %%
temp = []
for x, y in zip(*high_corr_var):
    if x!=y and x<y:
        print(train_corr.columns[x], train_corr.columns[y])
        temp.append((train_corr.columns[x],train_corr.columns[y]))
high_corr_var=temp
# Out:
# spkts sbytes
# spkts sloss
# dpkts dbytes
# dpkts dloss
# sbytes sloss
# dbytes dloss
# swin dwin
# ct_srv_src ct_dst_src_ltm
# ct_srv_src ct_srv_dst
# ct_dst_ltm ct_src_dport_ltm
# ct_dst_src_ltm ct_srv_dst
# is_ftp_login ct_ftp_cmd

# %%
high_corr_var
# Out:
# [('spkts', 'sbytes'),
#  ('spkts', 'sloss'),
#  ('dpkts', 'dbytes'),
#  ('dpkts', 'dloss'),
#  ('sbytes', 'sloss'),
#  ('dbytes', 'dloss'),
#  ('swin', 'dwin'),
#  ('ct_srv_src', 'ct_dst_src_ltm'),
#  ('ct_srv_src', 'ct_srv_dst'),
#  ('ct_dst_ltm', 'ct_src_dport_ltm'),
#  ('ct_dst_src_ltm', 'ct_srv_dst'),
#  ('is_ftp_login', 'ct_ftp_cmd')]

# %% [markdown]
# ## sbytes , sloss , spkts

# %%
print(train[['sbytes','sloss','spkts']].corr())        # ??????????????  why these 3
# Out:
#           sbytes     sloss     spkts
# sbytes  1.000000  0.996109  0.963791
# sloss   0.996109  1.000000  0.971069
# spkts   0.963791  0.971069  1.000000

# %%
sns.heatmap(train[['sbytes','sloss','spkts']].corr(), annot=True)
plt.show()

# %% [markdown]
# - so we can drop column sbyte from above representation.
# - From this visualization we can see that both have high correlation and same distribution with other columns

# %% [markdown]
# ## dbytes     dloss     dpkts

# %%
print(train[['dbytes','dloss','dpkts']].corr())
# Out:
#           dbytes     dloss     dpkts
# dbytes  1.000000  0.996504  0.971907
# dloss   0.996504  1.000000  0.978636
# dpkts   0.971907  0.978636  1.000000

# %%
sns.heatmap(train[['dbytes','dloss','dpkts']].corr(), annot=True)
plt.show()

# %% [markdown]
# - so we can drop column dbytes from above representation.
# - From this visualization we can see that both have high correlation and same distribution with other columns

# %% [markdown]
# ## ct_dst_src_ltm  ct_srv_src  ct_srv_dst

# %%
print(train[['ct_dst_src_ltm','ct_srv_src','ct_srv_dst']].corr())
# Out:
#                 ct_dst_src_ltm  ct_srv_src  ct_srv_dst
# ct_dst_src_ltm        1.000000    0.967138    0.972370
# ct_srv_src            0.967138    1.000000    0.980323
# ct_srv_dst            0.972370    0.980323    1.000000

# %%
obj=sns.heatmap(train[['ct_dst_src_ltm','ct_srv_src','ct_srv_dst']].corr(), annot=True)
for labelx, labely in zip(obj.get_xticklabels(), obj.get_yticklabels()):
    labelx.set_rotation(15)
    labely.set_rotation(0)
plt.show()

# %% [markdown]
# - we can drop column ct_srv_dst
# - From this visualization we can see that three columns are having high correlation and same distribution

# %% [markdown]
# ## swin     dwin

# %%
print(train[['swin','dwin']].corr())
# Out:
#          swin     dwin
# swin  1.00000  0.99014
# dwin  0.99014  1.00000

# %%
obj=sns.heatmap(train[['swin', 'dwin']].corr(), annot=True)
for labelx, labely in zip(obj.get_xticklabels(), obj.get_yticklabels()):
    labelx.set_rotation(15)
    labely.set_rotation(0)
plt.show()

# %% [markdown]
# ## is_ftp_login  ct_ftp_cmd

# %%
print(train[['is_ftp_login','ct_ftp_cmd']].corr())
# Out:
#               is_ftp_login  ct_ftp_cmd
# is_ftp_login           1.0         1.0
# ct_ftp_cmd             1.0         1.0

# %%
obj=sns.heatmap(train[['is_ftp_login', 'ct_ftp_cmd']].corr(), annot=True)
for labelx, labely in zip(obj.get_xticklabels(), obj.get_yticklabels()):
    labelx.set_rotation(15)
    labely.set_rotation(0)
plt.show()

# %% [markdown]
# - we can drop ct_ftp_cmd.
# - From this visualization we can see that both have high correlation and same distribution

# %% [markdown]
# # 3.5 EDA conclusion

# %% [markdown]
# #### we can drop the 5 columns mentioned from above analysis which are highly correlated
# - sbyte and dbytes
# - ct_srv_dst
# - ct_ftp_cmd
# - dwin

# %%
cols_to_drop = ['sbytes', 'dbytes','ct_srv_dst', 'ct_ftp_cmd', 'dwin']

# %%
train.drop(columns=cols_to_drop, inplace=True)
train.shape
# Out:
# (175341, 40)

# %%
test=pd.read_csv(r"C:\Users\alok\Documents\ML_Deep_Learning_stuff/UNSW_NB15_testing-set.csv", na_values=["-"])
test
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0          1  0.000011   udp     NaN   INT      2      0     496       0
# 1          2  0.000008   udp     NaN   INT      2      0    1762       0
# 2          3  0.000005   udp     NaN   INT      2      0    1068       0
# 3          4  0.000006   udp     NaN   INT      2      0     900       0
# 4          5  0.000010   udp     NaN   INT      2      0    2126       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 82327  82328  0.000005   udp     NaN   INT      2      0     104       0
# 82328  82329  1.106101   tcp     NaN   FIN     20      8   18062     354
# 82329  82330  0.000000   arp     NaN   INT      1      0      46       0
# 82330  82331  0.000000   arp     NaN   INT      1      0      46       0
# 82331  82332  0.000009   udp     NaN   INT      2      0     104       0
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0       90909.090200  ...                 1               2             0
# 1      125000.000300  ...                 1               2             0
# 2      200000.005100  ...                 1               3             0
# 3      166666.660800  ...                 1               3             0
# 4      100000.002500  ...                 1               3             0
# ...              ...  ...               ...             ...           ...
# 82327  200000.005100  ...                 1               2             0
# 82328      24.410067  ...                 1               1             0
# 82329       0.000000  ...                 1               1             0
# 82330       0.000000  ...                 1               1             0
# 82331  111111.107200  ...                 1               1             0
#
#        ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0               0                 0           1           2                0
# 1               0                 0           1           2                0
# 2               0                 0           1           3                0
# 3               0                 0           2           3                0
# 4               0                 0           2           3                0
# ...           ...               ...         ...         ...              ...
# 82327           0                 0           2           1                0
# 82328           0                 0           3           2                0
# 82329           0                 0           1           1                1
# 82330           0                 0           1           1                1
# 82331           0                 0           1           1                0
#
#        attack_cat  label
# 0          Normal      0
# 1          Normal      0
# 2          Normal      0
# 3          Normal      0
# 4          Normal      0
# ...           ...    ...
# 82327      Normal      0
# 82328      Normal      0
# 82329      Normal      0
# 82330      Normal      0
# 82331      Normal      0
#
# [82332 rows x 45 columns]

# %%
print(train.shape, test.shape)
# Out:
# (175341, 40) (82332, 45)

# %%
test.drop(columns=cols_to_drop, inplace=True)
test.shape
# Out:
# (82332, 40)

# %%
df=pd.concat([train,test], sort=False, axis=0)
df
# Out:
#           id       dur proto service state  spkts  dpkts           rate  sttl  \
# 0          1  0.121478   tcp     NaN   FIN      6      4      74.087490   252
# 1          2  0.649902   tcp     NaN   FIN     14     38      78.473372    62
# 2          3  1.623129   tcp     NaN   FIN      8     16      14.170161    62
# 3          4  1.681642   tcp     ftp   FIN     12     12      13.677108    62
# 4          5  0.449454   tcp     NaN   FIN     10      6      33.373826   254
# ...      ...       ...   ...     ...   ...    ...    ...            ...   ...
# 82327  82328  0.000005   udp     NaN   INT      2      0  200000.005100   254
# 82328  82329  1.106101   tcp     NaN   FIN     20      8      24.410067   254
# 82329  82330  0.000000   arp     NaN   INT      1      0       0.000000     0
# 82330  82331  0.000000   arp     NaN   INT      1      0       0.000000     0
# 82331  82332  0.000009   udp     NaN   INT      2      0  111111.107200   254
#
#        dttl  ...  ct_dst_ltm  ct_src_dport_ltm  ct_dst_sport_ltm  \
# 0       254  ...           1                 1                 1
# 1       252  ...           1                 1                 1
# 2       252  ...           2                 1                 1
# 3       252  ...           2                 1                 1
# 4       252  ...           2                 2                 1
# ...     ...  ...         ...               ...               ...
# 82327     0  ...           2                 1                 1
# 82328   252  ...           2                 1                 1
# 82329     0  ...           1                 1                 1
# 82330     0  ...           1                 1                 1
# 82331     0  ...           1                 1                 1
#
#        ct_dst_src_ltm  is_ftp_login  ct_flw_http_mthd  ct_src_ltm  \
# 0                   1             0                 0           1
# 1                   2             0                 0           1
# 2                   3             0                 0           2
# 3                   3             1                 0           2
# 4                  40             0                 0           2
# ...               ...           ...               ...         ...
# 82327               2             0                 0           2
# 82328               1             0                 0           3
# 82329               1             0                 0           1
# 82330               1             0                 0           1
# 82331               1             0                 0           1
#
#        is_sm_ips_ports  attack_cat  label
# 0                    0      Normal      0
# 1                    0      Normal      0
# 2                    0      Normal      0
# 3                    0      Normal      0
# 4                    0      Normal      0
# ...                ...         ...    ...
# 82327                0      Normal      0
# 82328                0      Normal      0
# 82329                1      Normal      0
# 82330                1      Normal      0
# 82331                0      Normal      0
#
# [257673 rows x 40 columns]

# %%
def col_gen (labels, col_name, df):
    for label in labels:
        df[label]=np.where(df[col_name]==label,1,0)

# %%
df.isnull().sum()
# Out:
# id                        0
# dur                       0
# proto                     0
# service              141321
# state                     0
# spkts                     0
# dpkts                     0
# rate                      0
# sttl                      0
# dttl                      0
# sload                     0
# dload                     0
# sloss                     0
# dloss                     0
# sinpkt                    0
# dinpkt                    0
# sjit                      0
# djit                      0
# swin                      0
# stcpb                     0
# dtcpb                     0
# tcprtt                    0
# synack                    0
# ackdat                    0
# smean                     0
# dmean                     0
# trans_depth               0
# response_body_len         0
# ct_srv_src                0
# ct_state_ttl              0
# ct_dst_ltm                0
# ct_src_dport_ltm          0
# ct_dst_sport_ltm          0
# ct_dst_src_ltm            0
# is_ftp_login              0
# ct_flw_http_mthd          0
# ct_src_ltm                0
# is_sm_ips_ports           0
# attack_cat                0
# label                     0
# dtype: int64

# %%
categorical_cols = df.select_dtypes(include=object).columns
categorical_cols
# Out:
# Index(['proto', 'service', 'state', 'attack_cat'], dtype='object')

# %%
for col in categorical_cols:
    print(df[col].value_counts())
# Out:
# tcp      123041
# udp       92701
# unas      15599
# arp        3846
# ospf       3271
#           ...
# crtp        131
# argus       131
# igmp         48
# icmp         15
# rtp           1
# Name: proto, Length: 133, dtype: int64
# dns         68661
# http        27011
# smtp         6909
# ftp-data     5391
# ftp          4980
# pop3         1528
# ssh          1506
# dhcp          120
# snmp          109
# ssl            86
# irc            30
# radius         21
# Name: service, dtype: int64
# FIN    117164
# INT    116438
# CON     20134
# REQ      3833
# RST        84
# ECO        12
# ACC         4
# PAR         1
# no          1
# CLO         1
# URN         1
# Name: state, dtype: int64
# Normal            93000
# Generic           58871
# Exploits          44525
# Fuzzers           24246
# DoS               16353
# Reconnaissance    13987
# Analysis           2677
# Backdoor           2329
# Shellcode          1511
# Worms               174
# Name: attack_cat, dtype: int64

# %%
services=df["service"].value_counts().head(7)#.index
print(services)
# Out:
# dns         68661
# http        27011
# smtp         6909
# ftp-data     5391
# ftp          4980
# pop3         1528
# ssh          1506
# Name: service, dtype: int64

# %%
print(df.shape)
# Out:
# (257673, 40)

# %%
col_gen(services,"service", df)

# %%
print(df.shape)
# Out:
# (257673, 47)

# %%
df.drop(labels="service", axis=1, inplace= True)

# %%
print(df.shape)
# Out:
# (257673, 46)

# %%
states=df["state"].value_counts().head(4)#.index
print(states)
# Out:
# FIN    117164
# INT    116438
# CON     20134
# REQ      3833
# Name: state, dtype: int64

# %%
print(df.shape)
# Out:
# (257673, 46)

# %%
col_gen(states,"state", df)

# %%
print(df.shape)
# Out:
# (257673, 50)

# %%
df.drop(labels="state", axis=1, inplace= True)

# %%
print(df.shape)
# Out:
# (257673, 49)

# %%
protocols=df["proto"].value_counts().head(6)#.index
print(protocols)
# Out:
# tcp     123041
# udp      92701
# unas     15599
# arp       3846
# ospf      3271
# sctp      1474
# Name: proto, dtype: int64

# %%
print(df.shape)
# Out:
# (257673, 49)

# %%
col_gen(protocols,"proto", df)

# %%
print(df.shape)
# Out:
# (257673, 55)

# %%
df.drop(labels="proto", axis=1, inplace= True)

# %%
print(df.shape)
# Out:
# (257673, 54)

# %%
attack_cats=df["attack_cat"].value_counts().head(6)#.index
print(attack_cats)
# Out:
# Normal            93000
# Generic           58871
# Exploits          44525
# Fuzzers           24246
# DoS               16353
# Reconnaissance    13987
# Name: attack_cat, dtype: int64

# %%
print(df.shape)
# Out:
# (257673, 54)

# %%
col_gen(attack_cats,"attack_cat", df)

# %%
print(df.shape)
# Out:
# (257673, 60)

# %%
df.drop(labels="attack_cat", axis=1, inplace= True)

# %%
print(df.shape)
# Out:
# (257673, 59)

# %%
df.columns
# Out:
# Index([               'id',               'dur',             'spkts',
#                    'dpkts',              'rate',              'sttl',
#                     'dttl',             'sload',             'dload',
#                    'sloss',             'dloss',            'sinpkt',
#                   'dinpkt',              'sjit',              'djit',
#                     'swin',             'stcpb',             'dtcpb',
#                   'tcprtt',            'synack',            'ackdat',
#                    'smean',             'dmean',       'trans_depth',
#        'response_body_len',        'ct_srv_src',      'ct_state_ttl',
#               'ct_dst_ltm',  'ct_src_dport_ltm',  'ct_dst_sport_ltm',
#           'ct_dst_src_ltm',      'is_ftp_login',  'ct_flw_http_mthd',
#               'ct_src_ltm',   'is_sm_ips_ports',             'label',
#                      68661,               27011,                6909,
#                       5391,                4980,                1528,
#                       1506,              117164,              116438,
#                      20134,                3833,              123041,
#                      92701,               15599,                3846,
#                       3271,                1474,               93000,
#                      58871,               44525,               24246,
#                      16353,               13987],
#       dtype='object')

# %%
Y=df["label"]
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 82327    0
# 82328    0
# 82329    0
# 82330    0
# 82331    0
# Name: label, Length: 257673, dtype: int64

# %%
X = df.drop(labels="label", axis=1)

# %%
Y = Y.values.reshape(-1,1)

# %%
print(Y.shape)
# Out:
# (257673, 1)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X=ss.fit_transform(X)

# %%
print(X.shape, Y.shape)
# Out:
# (257673, 58) (257673, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25)

# %%
print(X_train.shape)
X_train
# Out:
# (193254, 58)
# array([[-0.54242632, -0.09206479, -0.07191885, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.07410253, -0.16701624, -0.07191885, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.04247259, -0.2086784 , -0.13076536, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.36795195, -0.20867857, -0.13076536, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.25664008, -0.20867924, -0.13076536, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.61727903, -0.0953984 , -0.07191885, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
print(Y_train.shape)
# Out:
# (193254, 1)

# %% [markdown]
# ## logistic regression

# %%
from sklearn.linear_model import LogisticRegression
log_clf = LogisticRegression(random_state=42)

# %%
log_clf.fit(X_train, Y_train)
y_pred=log_clf.predict(X_test)
y_pred = y_pred.reshape(-1, 1)
# Out:
# C:\Users\alok\Anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\alok\Anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.metrics import f1_score
log_f1_score = f1_score(Y_test, y_pred)
log_f1_score
# Out:
# 0.9187096774193548

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[17910,  5221],
#        [ 1772, 39516]], dtype=int64)

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(log_clf, X_test, Y_test, cmap=plt.cm.Blues, normalize='true')
disp.confusion_matrix
# Out:
# array([[0.77428559, 0.22571441],
#        [0.04291804, 0.95708196]])

# %%
from sklearn.metrics import accuracy_score
log_accs=accuracy_score(Y_test,y_pred)
log_accs
# Out:
# 0.8914450705537186

# %%
from sklearn.metrics import precision_score
log_precision = precision_score(Y_test, y_pred, average='binary')
log_precision
# Out:
# 0.8832957060151553

# %%
from sklearn.metrics import recall_score
log_recall = recall_score(Y_test, y_pred, labels=[1,2], average='micro')
log_recall
# Out:
# 0.9570819608602984

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

# %%
svm_clf = Pipeline((
("scaler", StandardScaler()),
("linear_svc", LinearSVC(C=1, loss="hinge")),
))

# %%
svm_clf.fit(X_train, Y_train)
# Out:
# C:\Users\alok\Anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\alok\Anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Pipeline(memory=None,
#          steps=[('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('linear_svc',
#                  LinearSVC(C=1, class_weight=None, dual=True,
#                            fit_intercept=True, intercept_scaling=1,
#                            loss='hinge', max_iter=1000, multi_class='ovr',
#                            penalty='l2', random_state=None, tol=0.0001,
#                            verbose=0))],
#          verbose=False)

# %%
y_pred=svm_clf.predict(X_test)
y_pred = y_pred.reshape(-1, 1)

# %%
from sklearn.metrics import f1_score
svm_f1_score = f1_score(Y_test, y_pred)
svm_f1_score
# Out:
# 0.9207743688441072

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[16755,  6376],
#        [  622, 40666]], dtype=int64)

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(svm_clf, X_test, Y_test, cmap=plt.cm.Blues, normalize='true')
disp.confusion_matrix
# Out:
# array([[0.7243526 , 0.2756474 ],
#        [0.01506491, 0.98493509]])

# %%
from sklearn.metrics import accuracy_score
svm_accs=accuracy_score(Y_test,y_pred)
svm_accs
# Out:
# 0.8913674537015477

# %%
from sklearn.metrics import precision_score
svm_precision = precision_score(Y_test, y_pred, average='binary')
svm_precision
# Out:
# 0.8644615450023383

# %%
from sklearn.metrics import recall_score
svm_recall = recall_score(Y_test, y_pred, labels=[1,2], average='micro')
svm_recall
# Out:
# 0.9849350900988181

# %% [markdown]
# ## Neural network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

# %% [markdown]
# we don't set conditions for input layer

# %%
classifier.add(Dense(units = 30, kernel_initializer = "he_uniform", input_dim = 58, activation = "relu"))      # 1st hidden layer

# %%
classifier.add(Dropout(0.3))

# %%
classifier.add(Dense(units = 30, kernel_initializer = "he_uniform",activation = "relu"))    # 2nd hidden layer

# %%
classifier.add(Dropout(0.3))

# %%
classifier.add(Dense(units = 30, kernel_initializer = "he_uniform", activation = "relu"))    # 3rd hidden layer

# %%
classifier.add(Dense(units = 1, kernel_initializer = "glorot_uniform", activation = "sigmoid"))   # output layer   #activation = "softmax" if we had more than 2 classes in target

# %%
classifier.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])                    #loss = "categorical_crossentropy"  if more than 2 classes in target

# %%
classifier.fit(X_train, Y_train, batch_size = 100, epochs = 10, validation_data=(X_test, Y_test))       #batch size tells that after training that many examples the parameters will be updated
# Out:
# Train on 193254 samples, validate on 64419 samples
# Epoch 1/10
# 193254/193254 [==============================] - 5s 25us/sample - loss: 0.2556 - accuracy: 0.8811 - val_loss: 0.1648 - val_accuracy: 0.9164
# Epoch 2/10
# 193254/193254 [==============================] - 4s 22us/sample - loss: 0.1755 - accuracy: 0.9158 - val_loss: 0.1416 - val_accuracy: 0.9338
# Epoch 3/10
# 193254/193254 [==============================] - 4s 21us/sample - loss: 0.1580 - accuracy: 0.9262 - val_loss: 0.1349 - val_accuracy: 0.9375
# Epoch 4/10
# 193254/193254 [==============================] - 4s 21us/sample - loss: 0.1504 - accuracy: 0.9305 - val_loss: 0.1348 - val_accuracy: 0.9373
# Epoch 5/10
# 193254/193254 [==============================] - 4s 22us/sample - loss: 0.1457 - accuracy: 0.9328 - val_loss: 0.1282 - val_accuracy: 0.9440
# Epoch 6/10
# 193254/193254 [==============================] - 4s 21us/sample - loss: 0.1416 - accuracy: 0.9351 - val_loss: 0.1256 - val_accuracy: 0.9446
# Epoch 7/10
# 193254/193254 [==============================] - 4s 22us/sample - loss: 0.1400 - accuracy: 0.9367 - val_loss: 0.1269 - val_accuracy: 0.9444
# Epoch 8/10
# 193254/193254 [==============================] - 4s 21us/sample - loss: 0.1391 - accuracy: 0.9369 - val_loss: 0.1265 - val_accuracy: 0.9437
# Epoch 9/10
# 193254/193254 [==============================] - 4s 21us/sample - loss: 0.1365 - accuracy: 0.9384 - val_loss: 0.1235 - val_accuracy: 0.9457uracy
# Epoch 10/10
# 193254/193254 [==============================] - 4s 22us/sample - loss: 0.1363 - accuracy: 0.9380 - val_loss: 0.1232 - val_accuracy: 0.9463

# %%
ypred=classifier.predict(X_test)
ypred=(ypred>0.5)
ypred
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [ True],
#        [False],
#        [ True]])

# %%
from sklearn.metrics import f1_score
classifier_f1_score=f1_score(Y_test, y_pred)
classifier_f1_score
# Out:
# 0.9207743688441072

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,ypred)
cm
# Out:
# array([[21677,  1454],
#        [ 2007, 39281]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
classifier.accs=accuracy_score(Y_test,ypred)
classifier.accs
# Out:
# 0.946273614927273

# %%
from sklearn.metrics import precision_score
classifier_precision = precision_score(Y_test, y_pred, average='binary')
classifier_precision
# Out:
# 0.8644615450023383

# %%
from sklearn.metrics import recall_score
classifier_recall = recall_score(Y_test, y_pred, labels=[1,2], average='micro')
classifier_recall
# Out:
# 0.9849350900988181
